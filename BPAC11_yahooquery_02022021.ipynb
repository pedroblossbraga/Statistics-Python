# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroblossbraga/Statistics-Python/blob/master/BPAC11_yahooquery_02022021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## yahoo query
#
#
# Checando os atributos da biblioteca, e quais informações podem ser extraídas, utilizando a chave de símbolo de um ativo.
#
# https://pypi.org/project/yahooquery/

# %%
# !pip install yahooquery
# Out:
# ...
#      |████████████████████████████████| 51kB 2.8MB/s
# ...
#      |████████████████████████████████| 81kB 3.6MB/s
# ...
#      |████████████████████████████████| 5.5MB 7.0MB/s
# ...
#   Created wheel for requests-futures: filename=requests_futures-1.0.0-cp36-none-any.whl size=7013 sha256=4d3f53208fc0b9d013ffdd1162792be9c38800185503e61eedf06efe0397fe34
#   Stored in directory: /root/.cache/pip/wheels/26/d0/f5/dc4e4a37bbe55c9acf967d2bd899152412c1e49c227f5395ff
# Successfully built requests-futures
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
from yahooquery import Ticker

s = Ticker('BPAC11.SA')

s.summary_detail
# Out:
# {'BPAC11.SA': {'algorithm': None,
#   'ask': 98.87,
#   'askSize': 0,
#   'averageDailyVolume10Day': 2326316,
#   'averageVolume': 2221443,
#   'averageVolume10days': 2326316,
#   'beta': 1.534511,
#   'bid': 98.42,
#   'bidSize': 0,
#   'currency': 'BRL',
#   'dayHigh': 100.85,
#   'dayLow': 97.4,
#   'dividendRate': 1.25,
#   'dividendYield': 0.013200001,
#   'exDividendDate': '2021-01-07 00:00:00',
#   'fiftyDayAverage': 92.21848,
#   'fiftyTwoWeekHigh': 100.85,
#   'fiftyTwoWeekLow': 25.53,
#   'forwardPE': 27.761236,
#   'fromCurrency': None,
#   'lastMarket': None,
#   'marketCap': 20049049600,
#   'maxAge': 1,
#   'open': 100.53,
#   'previousClose': 98.47,
#   'priceHint': 2,
#   'priceToSalesTrailing12Months': 2.732106,
#   'regularMarketDayHigh': 100.85,
#   'regularMarketDayLow': 97.4,
#   'regularMarketOpen': 100.53,
#   'regularMarketPreviousClose': 98.47,
#   'regularMarketVolume': 3737800,
#   'toCurrency': None,
#   'tradeable': False,
# ...

# %%
s.__dict__
# Out:
# {'_country': 'united states',
#  '_default_query_params': {'corsDomain': 'finance.yahoo.com',
#   'lang': 'en-US',
#   'region': 'US'},
#  '_symbols': ['BPAC11.SA'],
#  'crumb': None,
#  'formatted': False,
#  'invalid_symbols': None,
#  'progress': False,
#  'session': <requests.sessions.Session at 0x7f7879fb9a58>}

# %%
dir(s)
# Out:
# ['CHUNK',
#  'CORPORATE_EVENTS',
#  'FUNDAMENTALS_OPTIONS',
#  'FUNDAMENTALS_TIME_ARGS',
#  'INTERVALS',
#  'MODULES',
#  'PERIODS',
#  '_CONFIG',
#  '_FUND_DETAILS',
#  '_MODULES_DICT',
#  '_STYLE_BOX',
#  '_VIZ_CONFIG',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adjust_ohlc',
#  '_async_requests',
#  '_chunk_symbols',
#  '_construct_data',
#  '_construct_params',
#  '_construct_urls',
#  '_country',
#  '_default_query_params',
#  '_financials',
#  '_financials_dataframes',
#  '_format_data',
#  '_fund_holdings',
#  '_get_data',
#  '_get_symbol',
#  '_historical_data_to_dataframe',
#  '_history_1m',
# ...

# %%
s.all_financial_data()
# Out:
#             asOfDate periodType  ...  TreasurySharesNumber  TreasuryStock
# symbol                           ...
# BPAC11.SA 2017-12-31        12M  ...            37836848.0     93063000.0
# BPAC11.SA 2018-12-31        12M  ...            19208052.0    128544000.0
# BPAC11.SA 2019-12-31        12M  ...             7236076.0    165784000.0
#
# [3 rows x 108 columns]

# %%
s.all_modules
# Out:
# {'BPAC11.SA': {'assetProfile': {'address1': 'Av. Brigadeiro Faria Lima, 3.477',
#    'address2': '14Âº Andar - Itaim Bibi',
#    'city': 'Sao Paulo',
#    'companyOfficers': [{'age': 48,
#      'exercisedValue': 0,
#      'maxAge': 1,
#      'name': 'Mr. Roberto  Balls Sallouti',
#      'title': 'CEO, Member of Management Board & Director',
#      'unexercisedValue': 0,
#      'yearBorn': 1972},
#     {'age': 50,
#      'exercisedValue': 0,
#      'maxAge': 1,
#      'name': 'Mr. Joao Marcello Dantas Leite',
#      'title': 'Exec. Officer, CFO, IRO & Member of Board of Exec. Officers',
#      'unexercisedValue': 0,
#      'yearBorn': 1970},
#     {'age': 77,
#      'exercisedValue': 0,
#      'maxAge': 1,
#      'name': 'Mr. Antonio Carlos Canto Porto Filho',
#      'title': 'Sr. VP, Exec. Officer & Member of Board of Exec. Officers',
#      'unexercisedValue': 0,
#      'yearBorn': 1943},
#     {'exercisedValue': 0,
#      'maxAge': 1,
#      'name': 'Mr. Guilherme  da Costa Paes',
# ...

# %%
s.asset_profile
# Out:
# {'BPAC11.SA': {'address1': 'Av. Brigadeiro Faria Lima, 3.477',
#   'address2': '14Âº Andar - Itaim Bibi',
#   'city': 'Sao Paulo',
#   'companyOfficers': [{'age': 48,
#     'exercisedValue': 0,
#     'maxAge': 1,
#     'name': 'Mr. Roberto  Balls Sallouti',
#     'title': 'CEO, Member of Management Board & Director',
#     'unexercisedValue': 0,
#     'yearBorn': 1972},
#    {'age': 50,
#     'exercisedValue': 0,
#     'maxAge': 1,
#     'name': 'Mr. Joao Marcello Dantas Leite',
#     'title': 'Exec. Officer, CFO, IRO & Member of Board of Exec. Officers',
#     'unexercisedValue': 0,
#     'yearBorn': 1970},
#    {'age': 77,
#     'exercisedValue': 0,
#     'maxAge': 1,
#     'name': 'Mr. Antonio Carlos Canto Porto Filho',
#     'title': 'Sr. VP, Exec. Officer & Member of Board of Exec. Officers',
#     'unexercisedValue': 0,
#     'yearBorn': 1943},
#    {'exercisedValue': 0,
#     'maxAge': 1,
#     'name': 'Mr. Guilherme  da Costa Paes',
# ...

# %%
s.balance_sheet()
# Out:
#             asOfDate periodType  ...  TreasurySharesNumber  TreasuryStock
# symbol                           ...
# BPAC11.SA 2017-12-31        12M  ...            37836848.0     93063000.0
# BPAC11.SA 2018-12-31        12M  ...            19208052.0    128544000.0
# BPAC11.SA 2019-12-31        12M  ...             7236076.0    165784000.0
#
# [3 rows x 51 columns]

# %%
s.calendar_events
# Out:
# {'BPAC11.SA': {'earnings': {'earningsDate': ['2021-02-12 00:00:S',
#     '2021-02-16 00:00:S'],
#    'revenueAverage': 1388920000,
#    'revenueHigh': 1388920000,
#    'revenueLow': 1388920000},
#   'exDividendDate': '2021-01-07 00:00:00',
#   'maxAge': 1}}

# %%
s.cash_flow()
# Out:
#             asOfDate periodType  ...  RepaymentOfDebt  RepurchaseOfCapitalStock
# symbol                           ...
# BPAC11.SA 2017-12-31        12M  ...              NaN                       NaN
# BPAC11.SA 2018-12-31        12M  ...    -1.862794e+09              -328085000.0
# BPAC11.SA 2019-12-31        12M  ...    -3.116466e+09               -37240000.0
# BPAC11.SA 2020-03-31        TTM  ...              NaN              -114306000.0
# BPAC11.SA 2020-09-30        TTM  ...              NaN              -119222000.0
#
# [5 rows x 19 columns]

# %%
s.company_officers
# Out:
#                maxAge  ... unexercisedValue
# symbol    row          ...
# BPAC11.SA 0         1  ...                0
#           1         1  ...                0
#           2         1  ...                0
#           3         1  ...                0
#           4         1  ...                0
#           5         1  ...                0
#           6         1  ...                0
#           7         1  ...                0
#           8         1  ...                0
#           9         1  ...                0
#
# [10 rows x 7 columns]

# %%
s.corporate_events
# Out:
#                            id  ...                          parentTopics
# symbol    date                 ...
# BPAC11.SA 2012-08-10  2588616  ...                           Performance
#           2012-12-20  2663807  ...                           Performance
#           2013-02-20  2697238  ...                           Performance
#           2013-08-07  2810538  ...                           Performance
#           2013-12-18  2889820  ...                           Performance
#           2014-02-19  2925268  ...                           Performance
#           2014-08-06  3044310  ...                           Performance
#           2015-01-02  3131685  ...                           Performance
#           2015-02-26  3162506  ...                           Performance
#           2015-07-01  3239848  ...                           Performance
#           2015-08-06  3260049  ...                           Performance
# ...

# %%
s.corporate_guidance
# Out:
#                            id  ...                          parentTopics
# symbol    date                 ...
# BPAC11.SA 2018-02-28  3776828  ...                    Corporate Guidance
#           2018-11-06  3931153  ...                    Corporate Guidance
#           2019-02-25  3987855  ...                    Corporate Guidance
#           2019-08-13  4080473  ...                    Corporate Guidance
#           2020-02-14  4168123  ...                    Corporate Guidance
#           2020-05-12  4216950  ...                    Corporate Guidance
#           2020-05-12  4217079  ...                    Corporate Guidance
#           2020-08-11  4259815  ...                    Corporate Guidance
#           2020-11-10  4302550  ...  Restructuring/Reorganization/Related
#           2020-11-10  4302459  ...                    Corporate Guidance
#
# [10 rows x 5 columns]

# %%
s.country
# Out:
# 'united states'

# %%
s.crumb

# %%
s.default_query_params
# Out:
# {'corsDomain': 'finance.yahoo.com', 'lang': 'en-US', 'region': 'US'}

# %%
s.earning_history
# Out:
#                maxAge  epsActual  ...     quarter  period
# symbol    row                     ...
# BPAC11.SA 0         1       0.74  ...  2017-12-31     -4q
#           1         1       0.74  ...  2018-03-31     -3q
#           2         1       0.71  ...  2018-06-30     -2q
#           3         1       0.78  ...  2018-09-30     -1q
#
# [4 rows x 7 columns]

# %%
s.earnings
# Out:
# {'BPAC11.SA': {'earningsChart': {'currentQuarterEstimateDate': '4Q',
#    'currentQuarterEstimateYear': 2018,
#    'earningsDate': ['2021-02-12 00:00:S', '2021-02-16 00:00:S'],
#    'quarterly': [{'actual': 0.74, 'date': '4Q2017', 'estimate': 0.74},
#     {'actual': 0.74, 'date': '1Q2018', 'estimate': 0.72},
#     {'actual': 0.71, 'date': '2Q2018', 'estimate': 0.74},
#     {'actual': 0.78, 'date': '3Q2018', 'estimate': 0.79}]},
#   'financialCurrency': 'BRL',
#   'financialsChart': {'quarterly': [{'date': '2Q2017',
#      'earnings': 502558000,
#      'revenue': 765806000},
#     {'date': '3Q2017', 'earnings': 500859000, 'revenue': 1670070000},
#     {'date': '4Q2017', 'earnings': 660379000, 'revenue': 1366149000},
#     {'date': '1Q2018', 'earnings': 600358000, 'revenue': 1481313000}],
#    'yearly': [{'date': 2014, 'earnings': 3369246000, 'revenue': 5602465000},
#     {'date': 2015, 'earnings': 5623498000, 'revenue': 3863700000},
# ...

# %%
s.earnings_trend
# Out:
# {'BPAC11.SA': {'maxAge': 1,
#   'trend': [{'earningsEstimate': {'avg': 0.0,
#      'growth': {},
#      'high': 0.0,
#      'low': 0.0,
#      'numberOfAnalysts': 0,
#      'yearAgoEps': 0.74},
#     'endDate': '2018-12-31',
#     'epsRevisions': {'downLast30days': 0,
#      'downLast90days': {},
#      'upLast30days': 1,
#      'upLast7days': 0},
#     'epsTrend': {'30daysAgo': 0.79,
#      '60daysAgo': 0.79,
#      '7daysAgo': 0.79,
#      '90daysAgo': 0.79,
#      'current': 0.0},
#     'growth': {},
#     'maxAge': 1,
#     'period': '0q',
#     'revenueEstimate': {'avg': 1388920000,
#      'growth': 0.0139999995,
#      'high': 1388920000,
#      'low': 1388920000,
#      'numberOfAnalysts': 1,
#      'yearAgoRevenue': 1370000000}},
#    {'earningsEstimate': {'avg': 0.0,
#      'growth': {},
#      'high': 0.0,
#      'low': 0.0,
#      'numberOfAnalysts': 0,
#      'yearAgoEps': 0.74},
#     'endDate': '2019-03-31',
#     'epsRevisions': {'downLast30days': 0,
# ...

# %%
s.esg_scores
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=esgScores'}

# %%
s.financial_data
# Out:
# {'BPAC11.SA': {'currentPrice': 98.83,
#   'earningsGrowth': -0.036,
#   'ebitdaMargins': 0.0,
#   'financialCurrency': 'BRL',
#   'grossMargins': 0.0,
#   'grossProfits': 5487472000,
#   'maxAge': 86400,
#   'numberOfAnalystOpinions': 4,
#   'operatingCashflow': -25048551424,
#   'operatingMargins': 0.40587002,
#   'profitMargins': 0.53504,
#   'recommendationKey': 'none',
#   'returnOnAssets': 0.01788,
#   'returnOnEquity': 0.1586,
#   'revenueGrowth': 0.489,
#   'revenuePerShare': 2.761,
#   'targetHighPrice': 30.0,
#   'targetLowPrice': 23.1,
#   'targetMeanPrice': 26.4,
#   'targetMedianPrice': 26.25,
#   'totalCash': 71402479616,
#   'totalCashPerShare': 26.321,
#   'totalDebt': 121269444608,
#   'totalRevenue': 7338313216}}

# %%
s.formatted
# Out:
# False

# %%
s.fund_bond_holdings
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.fund_bond_ratings
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.fund_category_holdings
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.fund_equity_holdings
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.fund_holding_info
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.fund_ownership
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
s.fund_performance
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=fundPerformance'}

# %%
s.fund_profile
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=fundProfile'}

# %%
s.fund_sector_weightings
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.fund_top_holdings
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=topHoldings'}

# %%
s.grading_history
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=upgradeDowngradeHistory'}

# %%
s.history()
# Out:
#                           close        low  ...   adjclose  dividends
# symbol    date                              ...
# BPAC11.SA 2021-01-04  93.080002  92.000000  ...  92.431747   0.000000
#           2021-01-05  92.379997  89.010002  ...  91.736618   0.000000
#           2021-01-06  89.400002  87.180000  ...  88.777374   0.000000
#           2021-01-07  89.339996  86.750000  ...  89.339996   0.622625
#           2021-01-08  92.169998  90.779999  ...  92.169998   0.000000
#           2021-01-11  90.010002  89.809998  ...  90.010002   0.000000
#           2021-01-12  90.809998  88.349998  ...  90.809998   0.000000
#           2021-01-13  91.320000  90.339996  ...  91.320000   0.000000
#           2021-01-14  91.510002  90.629997  ...  91.510002   0.000000
#           2021-01-15  89.610001  89.029999  ...  89.610001   0.000000
#           2021-01-18  92.879997  89.370003  ...  92.879997   0.000000
#           2021-01-19  94.690002  92.800003  ...  94.690002   0.000000
# ...

# %%
s.income_statement().T
# Out:
# symbol                                                        BPAC11.SA  ...            BPAC11.SA
# asOfDate                                            2017-12-31 00:00:00  ...  2020-09-30 00:00:00
# periodType                                                          12M  ...                  TTM
# Amortization                                                        NaN  ...                  NaN
# BasicAverageShares                                          2.73582e+09  ...                  NaN
# BasicEPS                                                           0.87  ...                  NaN
# DepreciationAndAmortizationInIncomeStatement                 6.5214e+07  ...            4.318e+07
# DepreciationIncomeStatement                                  6.5214e+07  ...           3.1353e+07
# DilutedAverageShares                                        2.73582e+09  ...                  NaN
# DilutedEPS                                                         0.87  ...                  NaN
# ...

# %%
s.index_trend
# Out:
# {'BPAC11.SA': {'estimates': [{'growth': 0.184, 'period': '0q'},
#    {'growth': 0.861, 'period': '+1q'},
#    {'growth': 0.102, 'period': '0y'},
#    {'growth': 0.174, 'period': '+1y'},
#    {'growth': 0.0753446, 'period': '+5y'},
#    {'period': '-5y'}],
#   'maxAge': 1,
#   'peRatio': 6.33115,
#   'pegRatio': 1.58861,
#   'symbol': 'SP5'}}

# %%
s.industry_trend
# Out:
# {'BPAC11.SA': {'estimates': [], 'maxAge': 1, 'symbol': None}}

# %%
s.insider_holders
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
s.insider_transactions
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=insiderTransactions'}

# %%
s.institution_ownership
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
s.invalid_symbols

# %%
s.key_stats
# Out:
# {'BPAC11.SA': {'52WeekChange': 0.31230843,
#   'SandP52WeekChange': 0.14442968,
#   'beta': 1.534511,
#   'bookValue': 9.603,
#   'category': None,
#   'earningsQuarterlyGrowth': -0.001,
#   'enterpriseToRevenue': 43.254,
#   'enterpriseValue': 317408706560,
#   'floatShares': 819861428,
#   'forwardEps': 3.56,
#   'fundFamily': None,
#   'heldPercentInsiders': 0.0,
#   'heldPercentInstitutions': 0.15734,
#   'impliedSharesOutstanding': 2644450048,
#   'lastDividendDate': 1609977600,
#   'lastDividendValue': 0.622625,
#   'lastFiscalYearEnd': '2019-12-31 00:00:00',
#   'lastSplitFactor': None,
#   'legalType': None,
#   'maxAge': 1,
#   'mostRecentQuarter': '2020-09-30 00:00:00',
#   'netIncomeToCommon': 3926320896,
#   'nextFiscalYearEnd': '2021-12-31 00:00:00',
#   'priceHint': 2,
#   'priceToBook': 10.291576,
#   'profitMargins': 0.53504,
#   'sharesOutstanding': 0,
#   'trailingEps': 1.477}}

# %%
s.major_holders
# Out:
# {'BPAC11.SA': {'insidersPercentHeld': 0.0,
#   'institutionsCount': 258,
#   'institutionsFloatPercentHeld': 0.15734,
#   'institutionsPercentHeld': 0.15734,
#   'maxAge': 1}}

# %%
dir(s.login)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
s.p_company_360
# Out:
# {'BPAC11.SA': 'User is not logged in'}

# %%
s.p_corporate_events
# Out:
# {'BPAC11.SA': 'User is not logged in'}

# %%
s.p_income_statement()
# Out:
# {'BPAC11.SA': 'User is not logged in'}

# %%
s.p_portal
# Out:
# 'User is not logged in'

# %%
s.p_technical_events
# Out:
# {'BPAC11.SA': {'total': 0}}

# %%
s.p_technical_insights
# Out:
# {'BPAC11.SA': 'User is not logged in'}

# %%
s.p_valuation_measures()
# Out:
# {'BPAC11.SA': 'User is not logged in'}

# %%
s.p_value_analyzer
# Out:
# 'HTTP 404 Not Found'

# %%
s.p_value_analyzer_drilldown
# Out:
# {'BPAC11.SA': 'User is not logged in'}

# %%
s.page_views
# Out:
# {'BPAC11.SA': 'No fundamentals data found for any of the summaryTypes=pageViews'}

# %%
s.price
# Out:
# {'BPAC11.SA': {'currency': 'BRL',
#   'currencySymbol': 'R$',
#   'exchange': 'SAO',
#   'exchangeDataDelayedBy': 0,
#   'exchangeName': 'Sao Paolo',
#   'fromCurrency': None,
#   'lastMarket': None,
#   'longName': 'Banco BTG Pactual S.A.',
#   'marketCap': 19990218752,
#   'marketState': 'POSTPOST',
#   'maxAge': 1,
#   'priceHint': 2,
#   'quoteSourceName': 'Delayed Quote',
#   'quoteType': 'EQUITY',
#   'regularMarketChange': 0.069999695,
#   'regularMarketChangePercent': 0.0007108733,
#   'regularMarketDayHigh': 100.85,
#   'regularMarketDayLow': 97.4,
#   'regularMarketOpen': 100.53,
#   'regularMarketPreviousClose': 98.47,
#   'regularMarketPrice': 98.54,
#   'regularMarketSource': 'DELAYED',
#   'regularMarketTime': '2021-02-02 20:54:58',
#   'regularMarketVolume': 3467800,
#   'shortName': 'BTGP BANCO  UNT     N2',
#   'symbol': 'BPAC11.SA',
#   'toCurrency': None,
#   'underlyingSymbol': None}}

# %%
s.quote_type
# Out:
# {'BPAC11.SA': {'exchange': 'SAO',
#   'firstTradeDateEpochUtc': '2017-02-24 13:00:00',
#   'gmtOffSetMilliseconds': -7200000,
#   'longName': 'Banco BTG Pactual S.A.',
#   'maxAge': 1,
#   'messageBoardId': 'finmb_947044',
#   'quoteType': 'EQUITY',
#   'shortName': 'BTGP BANCO  UNT     N2',
#   'symbol': 'BPAC11.SA',
#   'timeZoneFullName': 'America/Sao_Paulo',
#   'timeZoneShortName': 'BRT',
#   'underlyingSymbol': 'BPAC11.SA',
#   'uuid': 'bc078bb6-3c90-3fdc-82e1-9e45aed98d68'}}

# %%
s.quotes
# Out:
# {'BPAC11.SA': {'ask': 98.38,
#   'askSize': 0,
#   'averageDailyVolume10Day': 2326316,
#   'averageDailyVolume3Month': 2221443,
#   'bid': 98.42,
#   'bidSize': 0,
#   'bookValue': 9.603,
#   'currency': 'BRL',
#   'earningsTimestamp': 1605007800,
#   'earningsTimestampEnd': 1613471400,
#   'earningsTimestampStart': 1613125800,
#   'epsForward': 3.56,
#   'epsTrailingTwelveMonths': 1.477,
#   'esgPopulated': False,
#   'exchange': 'SAO',
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'America/Sao_Paulo',
#   'exchangeTimezoneShortName': 'BRT',
#   'fiftyDayAverage': 92.21848,
#   'fiftyDayAverageChange': 6.321518,
#   'fiftyDayAverageChangePercent': 0.06854936,
#   'fiftyTwoWeekHigh': 100.85,
#   'fiftyTwoWeekHighChange': -2.3099976,
#   'fiftyTwoWeekHighChangePercent': -0.02290528,
#   'fiftyTwoWeekLow': 25.53,
#   'fiftyTwoWeekLowChange': 73.01,
#   'fiftyTwoWeekLowChangePercent': 2.859773,
#   'fiftyTwoWeekRange': '25.53 - 100.85',
#   'financialCurrency': 'BRL',
# ...

# %%
s.quotes['BPAC11.SA']['market'], s.quotes['BPAC11.SA']['marketCap'], s.quotes['BPAC11.SA']['marketState']
# Out:
# ('br_market', 19990218752, 'POSTPOST')

# %%
s.recommendation_trend
# Out:
#               period  strongBuy  buy  hold  sell  strongSell
# symbol    row
# BPAC11.SA 0       0m          0    0     0     0           0
#           1      -1m          0    0     0     0           0
#           2      -2m          0    0     0     0           0
#           3      -3m          0    0     0     0           0

# %%
s.recommendations
# Out:
# {'BPAC11.SA': {'recommendedSymbols': [{'score': 0.094571,
#     'symbol': 'BPAN4.SA'},
#    {'score': 0.087163, 'symbol': 'B3SA3.SA'},
#    {'score': 0.086157, 'symbol': 'ENEV3.SA'},
#    {'score': 0.084432, 'symbol': 'RLOG3.SA'},
#    {'score': 0.0746, 'symbol': 'JPSA3.SA'}],
#   'symbol': 'BPAC11.SA'}}

# %%
s.share_purchase_activity
# Out:
# {'BPAC11.SA': {'buyInfoCount': 0,
#   'buyInfoShares': 0,
#   'maxAge': 1,
#   'netInfoCount': 0,
#   'netInfoShares': 0,
#   'period': '6m',
#   'sellInfoCount': 0,
#   'totalInsiderShares': 0}}

# %%
s.summary_profile
# Out:
# {'BPAC11.SA': {'address1': 'Av. Brigadeiro Faria Lima, 3.477',
#   'address2': '14Âº Andar - Itaim Bibi',
#   'city': 'Sao Paulo',
#   'companyOfficers': [],
#   'country': 'Brazil',
#   'industry': 'Capital Markets',
# ...

# %%
s.symbols
# Out:
# ['BPAC11.SA']

# %%
s.technical_insights
# Out:
# {'BPAC11.SA': {'sigDevs': [{'date': '2020-11-10',
#     'headline': "Brazil's Btg Pactual CFO sees return on equity above 20% in 2021"}],
#   'symbol': 'BPAC11.SA'}}

# %%
s.valuation_measures
# Out:
#             asOfDate periodType     MarketCap
# symbol
# BPAC11.SA 2018-06-27        TTM  1.996388e+10
